# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:\\Multi-pipeline-MLOps\\artifact\\14_04_2026_12_36_08\\data_ingestion\\ingested\\train.csv')

# %%
data.tail(3)
# Out:
#                                order_id order_status  \
# 79376  2c3f9230b4b5e62b5b75e294ecbb81b1    delivered
# 79377  ef2694b6887c4448f5daa99866191d84    delivered
# 79378  42479ac38bbf5cd9ae3c7925876075d9    delivered
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 79376          2018-03-05 23:45:55           2018-04-03 19:21:15
# 79377          2018-03-26 23:18:40           2018-04-10 13:19:13
# 79378          2018-01-15 22:38:31           2018-01-17 14:32:58
#
#       order_estimated_delivery_date                         review_id  \
# 79376           2018-04-06 00:00:00  c0868cef70a5ecec13bd0266aea1d0f8
# 79377           2018-04-19 00:00:00  a8d0a1f34f5be74436cb376f7dc8b566
# 79378           2018-01-30 00:00:00  baa780450a31d0923278baf75a532f3d
#
#        review_score review_comment_title          review_comment_message
# 79376             3                  NaN  Prazo muito longo para entrega
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79379 entries, 0 to 79378
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       79379 non-null  object
#  1   order_status                   79379 non-null  object
#  2   order_delivered_carrier_date   77995 non-null  object
#  3   order_delivered_customer_date  77125 non-null  object
#  4   order_estimated_delivery_date  79379 non-null  object
#  5   review_id                      79379 non-null  object
#  6   review_score                   79379 non-null  int64
#  7   review_comment_title           9255 non-null   object
#  8   review_comment_message         32796 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 5.5+ MB

# %%
data.isna().sum()
# Out:
# order_id                             0
# order_status                         0
# order_delivered_carrier_date      1384
# order_delivered_customer_date     2254
# order_estimated_delivery_date        0
# review_id                            0
# review_score                         0
# review_comment_title             70124
# review_comment_message           46583
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
